# %%
# !wget https://storage.googleapis.com/vit_models/imagenet21k/ViT-B_16.npz

# %%
# !git clone https://github.com/henilp105/ViT-pytorch

# %%
# !cp /kaggle/input/hymenoptera/hymenoptera_data ViT-pytorch/data -r
# !cp *npz ViT-pytorch/

# %%
# installing nvidia and building nvidia apex
# !git clone https://github.com/NVIDIA/apex
# !cd apex && pip install -v --disable-pip-version-check --no-cache-dir --no-build-isolation --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# %cd ViT-pytorch
# !pip install -r requirements.txt
# !python3 train.py --name Train_ants_bees --dataset ants_bees --model_type ViT-B_16 --pretrained_dir ViT-B_16.npz  --train_batch_size 64 --num_steps 1000
